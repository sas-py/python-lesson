# %% [markdown]
# <a href="https://colab.research.google.com/github/sas-py/python-lesson/blob/main/colab/2/2-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **if文による条件分岐**

# %%
age = 16
if age < 18:
    print('まだ選挙権がありません')

# %%
age = int(input('年齢を教えてください >>'))
if age < 18:
    print('まだ選挙権はありません')
    print('18歳になったら投票に行きましょう')
print('処理を終わります')

# %% [markdown]
# ### **条件式と比較演算子（関係演算子）**

# %%
a = 1
print(a == 1)
print(a != 1)
print(a > 1)
print(a < 1)
print(a >= 1)
print(a <= 1)

# %%
age = 18
if age == 18:
    print('18歳ですね。投票にいけますよ。')

# %% [markdown]
# ### **if～else文による条件分岐**

# %%
age = 18
if age < 18:
    print('まだ選挙権はありません')
else:
    print('投票に行きましょう')

# %% [markdown]
# ### **if～elif～else文による条件分岐**

# %%
age = 20
if age < 4:
    print('入場料は無料です')
elif age < 13:
    print('子供料金で入場できます')
else:
    print('大人料金が必要です')

# %% [markdown]
# ### **三項演算子**

# %%
a = 1
b = 10
c = a if a > b else b

print(c)

# %%
age = 18
if age < 18:
    print('まだ選挙権はありません')
else:
    print('投票に行きましょう')

# %%
age = 18
print('まだ選挙権はありません' if age < 18 else '投票に行きましょう')

# %% [markdown]
# ### **論理演算子による条件の組み合わせ**

# %%
a = 10
b = 5
print(a == 10 and b == 5)

a = 10
b = 7
print(a == 10 or b == 5)

# %% [markdown]
# ### **論理演算子**

# %%
age = 20
if age < 12 or age >= 65:
    print('入場料は無料です')
else:
    print('料金が必要です')

# %% [markdown]
# ### **演算子の優先度とカッコ**

# %%
a = 10
b = 5
print(a + 10 > b * 5)
print((a + 10) > (b * 5))

# %% [markdown]
# ### **比較演算子（関係演算子）の連結**

# %%
a = 6
print((a > 5) and (a < 10))

print(5 < a < 10)

# %% [markdown]
# ### **if文と真偽値**

# %%
a = True
if a == True:
    print(a)

# %%
a = True
if a:
    print(a)

# %%
a = False
if not a:
    print(a)

# %% [markdown]
# ### **BMIの計算**
# **計算方法の手順**
#
# *   体重を kg で測る
# *   身長を cm で測る
# *   身長を m に換算する
# *   「体重 ÷ 身長 ÷ 身長」 「体重（kg）÷ 身長（m）の2乗」
#
# **BMIの判定基準（日本肥満学会）**
#
# *   18.5未満：低体重（やせ）
# *   18.5〜25未満：普通体重（標準）
# *   25以上：肥満
#
# **身長160cm、体重55kgのBMIは約21.5**です。

# %%
weight = 55     # kg
height = 160    # cm
