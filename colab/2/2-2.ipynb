# %% [markdown]
# <a href="https://colab.research.google.com/github/sas-py/python-lesson/blob/main/colab/2/2-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **while文による処理の繰り返し**

# %% [markdown]
# ### **while文の例**

# %% [markdown]
# ### **for文による処理の繰り返し**

# %% [markdown]
# ### **for文の処理の流れ**

# %% [markdown]
# ### **rangeオブジェクト**

# %% [markdown]
# ### **ループ処理の流れの変更**

# %% [markdown]
# break：ループの処理を中断する

# %% [markdown]
# continue：ループ内の処理をスキップする

# %% [markdown]
# ### **ループ処理のネスト**
