# %% [markdown]
# <a href="https://colab.research.google.com/github/sas-py/python-lesson/blob/main/colab/index.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1 align="left">Pythonプログラミング入門<small>（基本編）</small></h1>
#
# ######この教材では、社内業務の効率化を目指して、Pythonの基本から自動化の基礎までを学びます。
# ######各リンクをクリックすると、それぞれの学習ページ（Google Colab）が新しいタブで開きます。
#
# ## 1. Pythonの基本知識
# * [（1）Pythonとは](https://google.com)
# * [（2）基本文法](https://google.com)
# * [（3）リスト](https://google.com)
#
# ## 2. 業務で使えるPython自動化基礎
# * [（1）制御フロー (1) if文](https://google.com)
# * [（2）制御フロー (2) while文、for文](https://google.com)
#
# ## 3. Python活用業務
# * [（1）関数（基礎・再利用）](https://google.com)
# * [（2）実践演習](https://google.com)
