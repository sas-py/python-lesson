# %% [markdown]
# <a href="https://colab.research.google.com/github/sas-py/python-lesson/blob/main/colab/1/1-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pythonとは、導入・クラウド環境確認

# %% [markdown]
# **キーワード**
#
# *   プログラム：コンピュータに与える命令を記述したもの。
# *   プログラミング言語：プログラムを作成するときに使用する言語。
# *   プログラムコード：プロフラムを、プログラミング言語を使って書いたもの。
# *   機械語：0と1だけを使って表現される命令文。
# *   コンパイル：プログラムコードを機械語に変換すること。
# *   コンパイラ：コンパイルを行うための専用プログラム。

# %% [markdown]
# **まとめ**
#
# *   プログラムとは、コンピュータに対する命令を記述したもの。
# *   Pythonというプログラミング言語を理解し、プログラムコードを記述できれば、コンピュータに命令を与えられる。
# *   プログラムコードを上から順番に機械語に変換しながら実行する方式をインタプリタ方式という。
# *   Pythonはインタプリタ方式を採用している。

# %% [markdown]
# **Pythonを動かしてみる**
#
# プログラムコードのルールとエラー
# *   プログラムコードは半角英数字と半角記号を使用して記述する
# *   プログラムコードの中の大文字と小文字は区別される
# *   上記のルールに従わないとプログラムコードが適切に解釈されずにエラーが発生し、そのエラーに関するエラーメッセージが表示される
# *   例えば<b>`print()`</b>を<b>`Print()`</b>と記述した場合

# %%
print(12 + 34)

# %%
print(45 - 12)

# %%
print(15 * 10)

# %%
print(90 / 2)

# %%
print(10 * (7 - 2) + 5)

# %%
print('Hello, Python.')

# %% [markdown]
# ### プログラミング言語の学習ではまず基本項目の学習から始めます。
#
# *   変数
# *   演算子（算術演算子、比較演算子、論理演算子）
# *   制御文（条件分岐・ループ）
# *   配列（Pytonではリスト）
# *   関数

# %% [markdown]
# *   Pythonは手続き型プログラミング、オブジェクト指向プログラミング両方に対応できる言語
#     *   手続き型: 処理の順番に沿ってコードを書く基本的な方法です。
#     *   オブジェクト指向: クラスとインスタンスを使い、データと処理をまとめて管理します。
#
# *   今回の学習は手続き型プログラミング
