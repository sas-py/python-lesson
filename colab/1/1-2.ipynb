# %% [markdown]
# <a href="https://colab.research.google.com/github/sas-py/python-lesson/blob/main/colab/1/1-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **文字列を扱う**

# %%
print('Hello, Python.')
print("Hello, Python.")
# Out:
# Hello, Python.
# Hello, Python.

# %% [markdown]
# ### **print関数**

# %%
print('Hello')
# Out:
# Hello

# %% [markdown]
# ### **プログラムコードのルール**

# %%
print('Hello')
# Out:
# Hello

# %%
Print('Hello')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1116/396548102.py in <cell line: 0>()
# ----> 1 Print('Hello')
#
# NameError: name 'Print' is not defined

# %%
print(3+4)
print(3 + 4)
# Out:
# 7
# 7

# %% [markdown]
# ### **変数**
# 「変数」とは、値を入れておく入れ物

# %%
a = 3
print(a)

# %% [markdown]
# ### **代入の正確なイメージ**
# 変数aに3を代入する

# %%
a = 3
print(a)
print(id(a))
# Out:
# 3
# 10446472

# %%
a = 2
b = a
print(id(a))
print(id(b))
print(a is b)
# Out:
# 10446440
# 10446440
# True

# %% [markdown]
# ### **インスタンスの同値性と同一性**

# %%
a = [1, 2, 4]
b =  [1, 2, 4]
print(id(a))
print(id(b))
print(a == b)
print(a is b)
# Out:
# 135228517523904
# 135229071837056
# True
# False

# %%
a = [1, 2, 4]
b = a
print(id(a))
print(id(b))
print(a == b)
print(a is b)
# Out:
# 135229073360192
# 135229073360192
# True
# True

# %% [markdown]
# ### **クラスとインスタンスとメソッド**

# %%
print('HELLO'.lower())
print('hello'.count('o'))
# Out:
# hello
# 1

# %%
my_list = [10, 20, 30]
my_list.reverse()
print(my_list)
# Out:
# [30, 20, 10]

# %%
my_list = [10, 20, 30]
print(my_list.pop())
print(my_list)
# Out:
# 30
# [10, 20]

# %% [markdown]
# ### **組み込み型**

# %%
print(10, type(10))
print(10.0, type(10.0))
print('10', type('10'))
print([10, 20, 30], type([10, 20, 30]))
# Out:
# 10 <class 'int'>
# 10.0 <class 'float'>
# 10 <class 'str'>
# [10, 20, 30] <class 'list'>

# %% [markdown]
# ### **メソッドの呼び出し**

# %%
print('Hello, Python'.count('o'))
# Out:
# 2

# %% [markdown]
# ### **代入した値を確認する**

# %%
a = 3
print(a)
# Out:
# 3

# %%
a = 10
b = 123
print(a, b)
# Out:
# 10 123

# %% [markdown]
# ### **３つのキーワード**
#
#
# *   変数
# *   代入
# *   参照

# %% [markdown]
# ### **値を変更する**

# %%
a = 3
print(a)
a = 5
print(a)
a = 'Hello'
print(a)
# Out:
# 3
# 5
# Hello

# %% [markdown]
# ### **型**

# %%
print(-1, type(-1))
print(0, type(0))
print(1, type(1))
print(2, type(2))
print(10, type(10))
print(100, type(100))

print(-0.12, type(-0.12))
print(0.0, type(0.0))
print(0.5, type(0.5))
print(2.34, type(2.34))

print('hello', type('hello'))
print('こんにちは', type('こんにちは'))

print(True, type(True))
print(False, type(False))
# Out:
# -1 <class 'int'>
# 0 <class 'int'>
# 1 <class 'int'>
# 2 <class 'int'>
# 10 <class 'int'>
# 100 <class 'int'>
# -0.12 <class 'float'>
# 0.0 <class 'float'>
# 0.5 <class 'float'>
# 2.34 <class 'float'>
# hello <class 'str'>
# こんにちは <class 'str'>
# True <class 'bool'>
# False <class 'bool'>

# %% [markdown]
# ### **type関数による型の確認**

# %%
print(type(10))
print(type(0.5))
print(type('こんにちは'))
print(type(True))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
a = 10
print(type(a))
b = 'こんにちは'
print(type(b))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# ### **算術演算**

# %%
print(1 + 3)
print(2 - 3)
print(2 * 3)
print(4 / 2)
print(7 // 3)
print(7 % 3)
print(2 ** 3)
print(a := 1)
print((a := 2) * 4)
# Out:
# 4
# -1
# 6
# 2.0
# 2
# 1
# 8
# 1
# 8

# %% [markdown]
# ### **変数を含む算術演算子**

# %%
a = 10
print(a + 3)

b = a + 3
print(b)

a = a + 3
print(a)
# Out:
# 13
# 13
# 13

# %% [markdown]
# ### **算術演算の短縮表現**
# 加算代入演算子（複合代入演算子）

# %%
a = 12
b = 3
a += b
print(a)

a = 12
b = 3
a -= b
print(a)

a = 12
b = 3
a *= b
print(a)

a = 7
b = 4
a /= b
print(a)

a = 12
b = 3
a %= b
print(a)

a = 7
b = 4
a //= b
print(a)

a = 2
b = 3
a **= b
print(a)
# Out:
# 15
# 9
# 36
# 1.75
# 0
# 1
# 8

# %% [markdown]
# ### **数値の型**

# %%
print(type(0))
print(type(0.0))
# Out:
# <class 'int'>
# <class 'float'>

# %% [markdown]
# ### **演算と数値の型**

# %%
print(type(3 + 2))
print(type(3 - 2))
print(type(3 * 2))
print(type(3 / 2))
print(type(4 / 2))
print(type(4 // 2))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'float'>
# <class 'int'>

# %% [markdown]
# ### **数値の型変換**

# %%
a = float(100)
print(a, type(a))

a = int(9.6)
print(a, type(a))
# Out:
# 100.0 <class 'float'>
# 9 <class 'int'>

# %% [markdown]
# ### **文字列の扱い**

# %% [markdown]
# +演算子による文字列の連結

# %%
a = 'AAA' + 'BBB'
print(a)

a = 'AAA'
b = 'BBB'
c = a + b
print(c)
# Out:
# AAABBB
# AAABBB

# %%
last_name = '山田'
first_name = '太郎'
name = last_name + first_name
print(name)
# Out:
# 山田太郎

# %%
month = '9月'
day = '25日'
message = '今日は' + month + day + 'です。'
print(message)
# Out:
# 今日は9月25日です。

# %% [markdown]
# *演算子による文字列の繰り返し

# %%
a = 'ABC' * 3
print(a)
# Out:
# ABCABCABC

# %%
message = 'Hello.' * 5
print(message)

# %% [markdown]
# ### **数値→文字列の変換**

# %%
a = 500 + '円'
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1116/3237769307.py in <cell line: 0>()
# ----> 1 a = 500 + '円'
#       2 print(a)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
a = str(500) + '円'
print(a)
# Out:
# 500円

# %%
year = 2026
print(str(year) + '年')
# Out:
# 2026年

# %% [markdown]
# ### **変数の値の埋め込み**

# %%
price = 550
print('この商品は' + str(price) + '円です')
# Out:
# この商品は550円です

# %%
price = 550
print(f'この商品は{price}円です')
# Out:
# この商品は550円です

# %% [markdown]
# ### **フォーマット文字列の活用**

# %%
b = 5
a = 550
print(f'この商品は1つ{a}円です。{b}個で{a * b}円です')
# Out:
# この商品は1つ550円です。5個で2750円です

# %%
num_item = 5
price = 550
print(f'この商品は1つ{price}円です。{num_item}個で{price * num_item}円です')
# Out:
# この商品は1つ550円です。5個で2750円です

# %% [markdown]
# ### **文字列→数値の変換**

# %% [markdown]
# int型への変換

# %%
a = '500'
b = a * 2
print(b)

a = '500'
b = int(a) * 2
print(b)
print(b, type(b))
# Out:
# 500500
# 1000
# 1000 <class 'int'>

# %% [markdown]
# float型への変換

# %%
a = '500'
b = float(a) * 2
print(b)
print(type(b))
# Out:
# 1000.0
# <class 'float'>

# %% [markdown]
# ### **len乱数による文字列の長さの取得**

# %%
print(len('Hello'))
print(len('Python'))
# Out:
# 5
# 6

# %% [markdown]
# ### **input関数を使ったキーボードからの入力の受け取り**

# %%
name = input('名前を入力してください\n')
print(name + 'さん、こんにちは')
# Out:
# 名前を入力してください
# 田中たかし
# 田中たかしさん、こんにちは

# %% [markdown]
# ### **エスケープシーケンス**

# %%
print('Hello, Python.')

print('Hello, \'Python\'.')
print('Hello, \"Python\".')
print('この商品は\\500です。')
print('Hello, \nPython.')
print('Hello, \tPython.')
print('Hello, \rPython.')
# Out:
# Hello, Python.
# Hello, 'Python'.
# Hello, "Python".
# この商品は\500です。
# Hello,
# Python.
# Hello, 	Python.
# Python.
