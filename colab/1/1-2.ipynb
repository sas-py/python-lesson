# %% [markdown]
# <a href="https://colab.research.google.com/github/sas-py/python-lesson/blob/main/colab/1/1-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **文字列を扱う**

# %%
print('Hello, Python.')
print("Hello, Python.")

# %% [markdown]
# ### **print関数**

# %%
print('Hello')

# %% [markdown]
# ### **プログラムコードのルール**

# %%
print('Hello')

# %%
Print('Hello')

# %%
print(3+4)
print(3 + 4)

# %% [markdown]
# ### **変数**
# 「変数」とは、値を入れておく入れ物

# %%
a = 3
print(a)

# %% [markdown]
# ### **代入の正確なイメージ**
# 変数aに3を代入する

# %%
a = 3
print(a)
print(id(a))

# %%
a = 2
b = a
print(id(a))
print(id(b))
print(a is b)

# %% [markdown]
# ### **インスタンスの同値性と同一性**

# %%
a = [1, 2, 4]
b =  [1, 2, 4]
print(id(a))
print(id(b))
print(a == b)
print(a is b)

# %%
a = [1, 2, 4]
b = a
print(id(a))
print(id(b))
print(a == b)
print(a is b)

# %% [markdown]
# ### **クラスとインスタンスとメソッド**

# %%
print('HELLO'.lower())
print('hello'.count('o'))

# %%
my_list = [10, 20, 30]
my_list.reverse()
print(my_list)

# %%
my_list = [10, 20, 30]
print(my_list.pop())
print(my_list)

# %% [markdown]
# ### **組み込み型**

# %%
print(10, type(10))
print(10.0, type(10.0))
print('10', type('10'))
print([10, 20, 30], type([10, 20, 30]))

# %% [markdown]
# ### **メソッドの呼び出し**

# %%
print('Hello, Python'.count('o'))

# %% [markdown]
# ### **代入した値を確認する**

# %%
a = 3
print(a)

# %%
a = 10
b = 123
print(a, b)

# %% [markdown]
# ### **３つのキーワード**
#
#
# *   変数
# *   代入
# *   参照

# %% [markdown]
# ### **値を変更する**

# %%
a = 3
print(a)
a = 5
print(a)
a = 'Hello'
print(a)

# %% [markdown]
# ### **型**

# %%
print(-1, type(-1))
print(0, type(0))
print(1, type(1))
print(2, type(2))
print(10, type(10))
print(100, type(100))
print()

print(-0.12, type(-0.12))
print(0.0, type(0.0))
print(0.5, type(0.5))
print(2.34, type(2.34))
print()

print('hello', type('hello'))
print('こんにちは', type('こんにちは'))
print()

print(True, type(True))
print(False, type(False))

# %% [markdown]
# ### **type関数による型の確認**

# %%
print(type(10))
print(type(0.5))
print(type('こんにちは'))
print(type(True))

# %%
a = 10
print(type(a))
b = 'こんにちは'
print(type(b))

# %% [markdown]
# ### **算術演算**

# %%
print(1 + 3)
print(2 - 3)
print(2 * 3)
print(4 / 2)
print(7 // 3)
print(7 % 3)
print(2 ** 3)
print(a := 1)
print((a := 2) * 4)

# %% [markdown]
# ### **変数を含む算術演算子**

# %%
a = 10
print(a + 3)

b = a + 3
print(b)

a = a + 3
print(a)

# %% [markdown]
# ### **算術演算の短縮表現**
# 加算代入演算子（複合代入演算子）

# %%
a = 12
b = 3
a += b
print(a)

a = 12
b = 3
a -= b
print(a)

a = 12
b = 3
a *= b
print(a)

a = 7
b = 4
a /= b
print(a)

a = 12
b = 3
a %= b
print(a)

a = 7
b = 4
a //= b
print(a)

a = 2
b = 3
a **= b
print(a)

# %% [markdown]
# ### **数値の型**

# %%
print(type(0))
print(type(0.0))

# %% [markdown]
# ### **演算と数値の型**

# %%
print(type(3 + 2))
print(type(3 - 2))
print(type(3 * 2))
print(type(3 / 2))
print(type(4 / 2))
print(type(4 // 2))

# %% [markdown]
# ### **数値の型変換**

# %%
a = float(100)
print(a, type(a))

a = int(9.6)
print(a, type(a))

# %% [markdown]
# ### **文字列の扱い**

# %% [markdown]
# +演算子による文字列の連結

# %%
a = 'AAA' + 'BBB'
print(a)

a = 'AAA'
b = 'BBB'
c = a + b
print(c)

# %%
last_name = '山田'
first_name = '太郎'
name = last_name + first_name
print(name)

# %%
month = '9月'
day = '25日'
message = '今日は' + month + day + 'です。'
print(message)

# %% [markdown]
# *演算子による文字列の繰り返し

# %%
a = 'ABC' * 3
print(a)

# %%
message = 'Hello.' * 5
print(message)

# %% [markdown]
# ### **数値→文字列の変換**

# %%
a = 500 + '円'
print(a)

# %%
a = str(500) + '円'
print(a)

# %%
year = 2026
print(str(year) + '年')

# %% [markdown]
# ### **変数の値の埋め込み**

# %%
price = 550
print('この商品は' + str(price) + '円です')

# %%
price = 550
print(f'この商品は{price}円です')

# %% [markdown]
# ### **フォーマット文字列の活用**

# %%
b = 5
a = 550
print(f'この商品は1つ{a}円です。{b}個で{a * b}円です')

# %%
num_item = 5
price = 550
print(f'この商品は1つ{price}円です。{num_item}個で{price * num_item}円です')

# %% [markdown]
# ### **文字列→数値の変換**

# %% [markdown]
# int型への変換

# %%
a = '500'
b = a * 2
print(b)

a = '500'
b = int(a) * 2
print(b)
print(b, type(b))

# %% [markdown]
# float型への変換

# %%
a = '500'
b = float(a) * 2
print(b)
print(type(b))

# %% [markdown]
# ### **len関数による文字列の長さの取得**

# %%
print(len('Hello'))
print(len('Python'))

# %% [markdown]
# ### **input関数を使ったキーボードからの入力の受け取り**

# %%
name = input('名前を入力してください\n')
print(name + 'さん、こんにちは')

# %% [markdown]
# ### **エスケープシーケンス**

# %%
print('Hello, Python.')

print('Hello, \'Python\'.')
print('Hello, \"Python\".')
print('この商品は\\500です。')
print('Hello, \nPython.')
print('Hello, \tPython.')
print('Hello, \rPython.')
